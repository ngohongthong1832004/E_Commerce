# %%
import pandas as pd

# %%
# read file parquet file
df = pd.read_parquet('category_11312.parquet')

# %%
df
# Out:
#              id            sku  \
# 0     274770492  8307739719094
# 1     269843858  9608781146118
# 2     269843844  2957883219352
# 3     269843837  7989649703770
# 4     269843812  4816722029579
# ...         ...            ...
# 1995  272069411  2317652954580
# 1996  263023592  4448540054549
# 1997  260922784  8528896224448
# 1998   15679309  1671408563801
# 1999    2077177  2592795806342
#
#                                                    name  \
# 0     [ KEY GIA HẠN hoặc MUA MỚI ] KEY ĐIỆN TỬ Phần ...
# 1                          Phiếu Quà Tặng GrabGifts 30K
# 2                          Phiếu Quà Tặng GrabGifts 50K
# 3                         Phiếu Quà Tặng GrabGifts 100K
# 4                         Phiếu Quà Tặng GrabGifts 200K
# ...                                                 ...
# 1995                  [E-Voucher] Đà Nẵng - Hội An 2N1Đ
# 1996  E-Voucher Núi Thần Tài - Gói phổ thông - Trẻ e...
# 1997  Tư Duy Nhanh Và Chậm - Nên Hay Không Nên Tin V...
# ...

# %%
df['impression_info'][0]
# Out:
# array([{'checksum': '', 'impression_id': 'thanos-8tTY9vNQSD0B9fz0-PCzfsueG', 'metadata': {'astra_reward': 0, 'category': 11312, 'delivery_date': None, 'delivery_info_badge_text': 'Thanh toán qua thẻ & ví', 'delivery_zone': 'VN039006001', 'discount_rate': 0, 'flags': {'_v': 'filter_revamp'}, 'is_ad': 0, 'is_astra_plus': 0, 'is_official_store': 0, 'is_tikinow': 0, 'is_tikipro': 0, 'is_trusted_store': 0, 'mpid': 274770492, 'params': {'_v': 'filter_revamp', 'category': '11312', 'limit': '100', 'page': '1'}, 'position': 1, 'price': 1289000, 'quantity_sold': 304, 'rating': 4.8, 'request_id': '8tTY9vNQSD0B9fz0', 'spid': 274770493, 'tiki_verified': 1}}],
#       dtype=object)
